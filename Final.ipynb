# %% [markdown]
# <a href="https://colab.research.google.com/github/Xin128/COMP576_CourseWork/blob/master/Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Download Data**

# %%
## step 1
# !pip uninstall -y kaggle
# !pip install --upgrade pip
# !pip install kaggle==1.5.6

# ## step 2 go to the link and copy the key into the box
from google.colab import drive
drive.mount('/content/gdrive')

# ## step 3
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/COMP576 Final Project"
# %cd /content/gdrive/My Drive/COMP576 Final Project
# !kaggle competitions download -c imet-2020-fgvc7

# # # ## step 4
# !unzip imet-2020-fgvc7.zip -d 123/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 123/train/f739e3a83b26c9d6e81fd30e03134a85.png
#   inflating: 123/train/f73aacb0f7e15e10972c74666e753fbf.png
#   inflating: 123/train/f73ae5b8eba7157d23cfaed8f7655759.png
#   inflating: 123/train/f73afa36e8f5f49d6385cc01919e383a.png
#   inflating: 123/train/f73bdc3a58a1454427b3ede31ac9191f.png
#   inflating: 123/train/f73c22a7c0d9ad2f5ed33e751a898f75.png
#   inflating: 123/train/f73c5aa9db6aa1638114392511e022c7.png
#   inflating: 123/train/f73c8a4ccf4959436cd0944a1d230ac3.png
#   inflating: 123/train/f73cc880d9cd35c3be4b95a059704640.png
#   inflating: 123/train/f73d5c425cfd6d013660cbb04252e4ed.png
#   inflating: 123/train/f73d6bd0832ac092e3735615ab46679a.png
#   inflating: 123/train/f73e530c46ec5b86602dc7b696c8fb1c.png
#   inflating: 123/train/f73e980a9329a7189096be88f74c8692.png
#   inflating: 123/train/f73f3397fb07f7c5f9002fa873e9cf86.png
#   inflating: 123/train/f73f45db70dd216f0a5b5f3880c4e419.png
# ...

# %%
import tensorflow as tf
import numpy as np

# %%
from google.colab import drive
drive.mount("/content/gdrive")

# %%
import pandas as pd
pd.read_csv('/content/gdrive/My Drive/COMP576 Final Project/train.csv')
# Out:
#                                       id                      attribute_ids
# 0       000040d66f14ced4cdd18cd95d91800f                       448 2429 782
# 1       0000ef13e37ef70412166725ec034a8a  2997 3231 2730 3294 3099 2017 784
# 2       0001eeb4a06e8daa7c6951bcd124c3c7                       2436 1715 23
# 3       000226398d224de78b191e6db45fd94e                  2997 3433 448 782
# 4       00029c3b0171158d63b1bbf803a7d750            3465 3322 3170 1553 781
# ...                                  ...                                ...
# 142114  fffd00c472c1856f5c8b7e41311e2344                      125 783 96 27
# 142115  fffdb3cde6cfd3b335fc56ecf2f1eae5             2732 3170 448 1559 785
# 142116  fffdde4325edb076dccea37978c1378a                  2813 233 1561 785
# 142117  fffe25dccc93a5e9e12f26d494dae26f       3095 408 1610 1470 1899 1449
# 142118  fffe66c4a175c96065551cebacb7636f          2788 3270 3170 946 783 29
#
# [142119 rows x 2 columns]

# %%
# Out:
#       attribute_id            attribute_name
# 0                0      country::afghanistan
# 1                1         country::alamania
# 2                2          country::algeria
# 3                3           country::arabia
# 4                4          country::armenia
# ...            ...                       ...
# 3469          3469             tags::writing
# 3470          3470  tags::writing implements
# 3471          3471              tags::zebras
# 3472          3472                tags::zeus
# 3473          3473              tags::zodiac
#
# [3474 rows x 2 columns]

# %% [markdown]
# # **Network**
# **1. ResNet 34, 50**
#
# **2. VGG 16**
#
# **3. InceptionNet3**
